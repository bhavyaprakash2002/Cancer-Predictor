# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_excel(r"C:\Users\Bhavya Prakash\Downloads\archive (2)\cancer patient data sets.xlsx")

# %%
data
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
target=data['Level']

# %%
target
# Out:
# 0         Low
# 1      Medium
# 2        High
# 3        High
# 4        High
#         ...
# 995      High
# 996      High
# 997      High
# 998      High
# 999      High
# Name: Level, Length: 1000, dtype: object

# %%
arr=[]

# %%
for i in range(1000):
    if target[i]=='Low':
        arr.append(0)
    elif target[i]=='Medium':
        arr.append(1)
    else:
        arr.append(2)

# %%
arr_np=np.array(arr)

# %%
arr_np_df=pd.DataFrame(arr_np)

# %%
data['Level_']=arr_np_df

# %%
data
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
data=data.drop('Level',axis=1)

# %%
data
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %% [markdown]
# # Checking for age

# %%
x=data['Balanced Diet']
y=data['Level_']

# %%
plt.scatter(x,y)
#plt.scatter(x1,y1)
plt.show()

# %%
data.columns
# Out:
# Index(['Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level_'],
#       dtype='object')

# %%
data=data.drop('Patient Id',axis=1)
data
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
x=data.iloc[:,:23]

# %%
x
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
y=data['Level_']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LogisticRegression
model_=LogisticRegression()
model_.fit(x_train,y_train)
# Out:
# C:\Users\Bhavya Prakash\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
train_score=model_.score(x_train,y_train)
test_score=model_.score(x_test,y_test)
print(train_score,test_score)
# Out:
# 0.996 0.996

# %%
['Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
       'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
       'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
       'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
       'Weight Loss', 'Shortness of Breath', 'Wheezing',
       'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
       'Dry Cough', 'Snoring', 'Level_']
x_=[43,2,6,1,3,1,1,1,6,3,1,1,1,1,3,1,1,1,1,1,2,2,3]

# %%
len(x_)
# Out:
# 23

# %%
x_np=np.array(x_)

# %%
x_df=pd.DataFrame(x_np)

# %%
x_df
# Out:
#      0
# 0   43
# 1    2
# 2    6
# 3    1
# 4    3
# 5    1
# 6    1
# 7    1
# 8    6
# 9    3
# 10   1
# 11   1
# 12   1
# 13   1
# 14   3
# 15   1
# 16   1
# 17   1
# 18   1
# 19   1
# 20   2
# 21   2
# 22   3

# %%
predict=model_.predict(x_df.T)
# Out:
# C:\Users\Bhavya Prakash\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print(predict)
# Out:
# [0]

# %%
x_=[20,1,5,1,3,1,3,2,6,5,1,1,2,1,5,2,1,1,1,1,1,1,1]
